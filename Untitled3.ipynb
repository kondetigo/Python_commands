# %% [markdown]
# <a href="https://colab.research.google.com/github/kondetigo/Python_commands/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Universities.csv')
plt.hist(df['SAT'])
# Out:
# (array([1., 3., 0., 0., 1., 2., 7., 4., 2., 5.]),
#  array([1005., 1046., 1087., 1128., 1169., 1210., 1251., 1292., 1333.,
#         1374., 1415.]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # New Section

# %%
plt.show()
sns.displot(df['SAT'])

# %%
import warnings
warnings.filterwarnings('ignore')
sns.displot(df['SAT'])

# %%
plt.plot(df['SAT'],df['Accept'],'rs')

# %%
sns.pairplot(df.iloc[1:3])

# %%
sns.pairplot(df.iloc[:,1:3])

# %%
plt.boxplot(df['SAT'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fcaa5bc3430>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fcaa5bc2f50>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fcaa5bc3550>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fcaa5b026e0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fcaa5b03130>],
#  'means': []}

# %%
import numpy as np
a=np.array([[1,2,3,4], [4,5,6,7]])

# %%
type(a)
a.size
# Out:
# 8

# %%
a.shape
a=a.reshape(4,2)
a
# Out:
# array([[1, 2],
#        [3, 4],
#        [4, 5],
#        [6, 7]])

# %%
a[2,0]
# Out:
# 4

# %%
df1=pd.DataFrame({ 'col1': ['7','15', '19','1099'], 'col2':[1,2,3,4] })

# %%
df1
# Out:
#    col1  col2
# 0     7     1
# 1    15     2
# 2    19     3
# 3  1099     4

# %%
print (df1)
# Out:
#    col1  col2
# 0     7     1
# 1    15     2
# 2    19     3
# 3  1099     4

# %%
df1.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# dtype: bool
